# %%
import pandas as pd
pd.set_option("display.max_rows", 10)

# %%
# Here the "index_col" option assigns the index to the colomn on the csv which, if not set as index, becomes the column "unnamed: 0"
reviewsNoIndex = pd.read_csv("./dataForKaggleNotes/winemag-data-130k-v2.csv")
reviewsWithIndex = pd.read_csv("./dataForKaggleNotes/winemag-data-130k-v2.csv", index_col=0)

# %%
reviewsWithIndex
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 0                                 Vulkà Bianco      87    NaN
# ...

# %%
canadian_youtube = pd.read_csv("./dataForKaggleNotes/CAvideos.csv")
british_youtube = pd.read_csv("./dataForKaggleNotes/GBvideos.csv")

# %%
left = canadian_youtube.set_index(['title', 'trending_date'])
right = british_youtube.set_index(['title', 'trending_date'])

# %%
left
# Out:
#                                                                      video_id  \
# title                                              trending_date
# Eminem - Walk On Water (Audio) ft. Beyoncé         17.14.11       n1WpP7iowLc
# PLUSH - Bad Unboxing Fan Mail                      17.14.11       0dBIkQ4Mz1M
# Racist Superman | Rudy Mancuso, King Bach & Lel... 17.14.11       5qpjK5DgCt4
# I Dare You: GOING BALD!?                           17.14.11       d380meD0W0M
# Ed Sheeran - Perfect (Official Music Video)        17.14.11       2Vv-BfVoq4g
# ...                                                                       ...
# HOW2: How to Solve a Mystery                       18.14.06       sGolxsMSGfQ
# Eli Lik Lik Episode 13 Partie 01                   18.14.06       8HNuRNi8t70
# KINGDOM HEARTS III – SQUARE ENIX E3 SHOWCASE 20... 18.14.06       GWlKEM3m2EE
# Trump Advisor Grovels To Trudeau                   18.14.06       lbMKLzQ4cNQ
# ...

# %%
right
# Out:
#                                                                      video_id  \
# title                                              trending_date
# John Lewis Christmas Ad 2017 - #MozTheMonster      17.14.11       Jw1Y-zhQURU
# Taylor Swift: …Ready for It? (Live) - SNL          17.14.11       3s1rvMFUweQ
# Eminem - Walk On Water (Audio) ft. Beyoncé         17.14.11       n1WpP7iowLc
# Goals from Salford City vs Class of 92 and Frie... 17.14.11       PUTEiSjKwJU
# Dashcam captures truck's near miss with child i... 17.14.11       rHwDegptbI4
# ...                                                                       ...
# Enrique Iglesias - MOVE TO MIAMI (Official Vide... 18.14.06       l884wKofd54
# Jacob Sartorius - Up With It (Official Music Vi... 18.14.06       IP8k2xkhOdI
# Anne-Marie - 2002 [Official Video]                 18.14.06       Il-an3K9pjg
# Eleni Foureira - Fuego - Cyprus - LIVE - First ... 18.14.06       -DRsfNObKIQ
# ...

# %%
joined = left.join(right, lsuffix='_CAN', rsuffix='_UK')

# %%
reviews = pd.read_csv("./dataForKaggleNotes/winemag-data-130k-v2.csv", index_col=0)
reviews
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 0                                 Vulkà Bianco      87    NaN
# ...

# %%
gaming_products = pd.read_csv("./dataForKaggleNotes/gaming.csv")
gaming_products['subreddit'] = "r/gaming"
movie_products = pd.read_csv("./dataForKaggleNotes/movies.csv")
movie_products['subreddit'] = "r/movies"

# %%
powerlifting_meets = pd.read_csv("./dataForKaggleNotes/meets.csv")
powerlifting_competitors = pd.read_csv("./dataForKaggleNotes/openpowerlifting.csv")
